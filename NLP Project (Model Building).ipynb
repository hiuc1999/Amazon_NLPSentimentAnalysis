# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from statistics import mean, stdev
from sklearn.metrics import f1_score

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
#import spacy
#from spacy.lang.en.stop_words import STOP_WORDS

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_text = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/df_text_nltk.csv')

# %%
df_text
# Out:
#         Positive                                               Text  \
# 0              1  I have bought several of the Vitality canned d...
# 1              0  Product arrived labeled as Jumbo Salted Peanut...
# 2              1  This is a confection that has been around a fe...
# 3              0  If you are looking for the secret ingredient i...
# 4              1  Great taffy at a great price.  There was a wid...
# ...          ...                                                ...
# 393928         1  Great for sesame chicken..this is a good if no...
# 393929         0  I'm disappointed with the flavor. The chocolat...
# 393930         1  These stars are small, so you can give 10-15 o...
# 393931         1  These are the BEST treats for training and rew...
# 393932         1  I am very satisfied ,product is as advertised,...
#
#                                             ProcessedText
# 0       bought sever vital can dog food product found ...
# 1       product arriv label jumbo salt peanut peanut a...
# 2       confect around centuri light pillowi citrus ge...
# 3       look secret ingredi robitussin believ found go...
# 4       great taffi great price wide assort yummi taff...
# ...                                                   ...
# 393928  great sesam chicken good not better restur eat...
# 393929  disappoint flavor chocol note especi weak milk...
# 393930  star small give one train session tri train do...
# 393931  best treat train reward dog good groom lower c...
# 393932  satisfi product advertis use cereal raw vinega...
#
# [393933 rows x 3 columns]

# %%
df_text.isnull().sum()
# Out:
# Positive         0
# Text             0
# ProcessedText    3
# dtype: int64

# %%
df_text['Positive'] = df_text['Positive'].astype("category")

# %%
df_text = df_text[df_text['ProcessedText'].notnull()] #drop the rows of null values

# %%
df_text = df_text.reset_index().drop('index',axis=1)

# %%
df_text.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 393930 entries, 0 to 393929
# Data columns (total 3 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Positive       393930 non-null  category
#  1   Text           393930 non-null  object
#  2   ProcessedText  393930 non-null  object
# dtypes: category(1), object(2)
# memory usage: 6.4+ MB

# %%
X = df_text['ProcessedText']
y = df_text['Positive']

# %% [markdown]
# ### Check if features need to be further cleaned

# %%
Tfidf_vec = TfidfVectorizer(stop_words='english', max_df=0.8, dtype= np.float32)

vectorizedX = Tfidf_vec.fit_transform(X)

vectorizedX.shape
# Out:
# (393930, 73780)

# %%
[feature for feature in Tfidf_vec.get_feature_names()]
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['aa',
#  'aaah',
#  'aabout',
#  'aabsolut',
#  'aachen',
#  'aack',
#  'aacur',
#  'aacut',
#  'aad',
#  'aadd',
#  'aadmit',
#  'aadp',
#  'aadult',
#  'aaf',
#  'aafco',
#  'aafter',
#  'aagh',
#  'aah',
#  'aahh',
#  'aahya',
#  'aain',
#  'aakaufman',
#  'aalmost',
#  'aaloo',
#  'aamazon',
#  'aamzon',
#  'aana',
#  'aand',
#  'aani',
#  'aanoth',
#  'aap',
#  'aar',
#  'aardvark',
#  'aargh',
#  'aaron',
#  'aaround',
#  'aarp',
#  'aarrggh',
#  'aarrgh',
#  'aarthur',
#  'aarti',
#  'aasanfood',
#  'aash',
#  'aauc',
#  'aaw',
#  'ab',
#  'aback',
#  'abalon',
#  'abamectin',
#  'abandn',
#  'abando',
#  'abandon',
#  'abaolut',
#  'abash',
#  'abat',
#  'abattoir',
#  'abb',
#  'abba',
#  'abbay',
#  'abbazabba',
#  'abberlin',
#  'abbey',
#  'abbi',
#  'abbondanza',
#  'abbot',
#  'abbott',
#  'abbrevi',
#  'abbypomeroy',
#  'abc',
#  'abcess',
#  'abcstor',
#  'abd',
#  'abdi',
#  'abdomen',
#  'abdomin',
#  'abduct',
#  'abdul',
#  'abe',
#  'abeja',
#  'abel',
#  'abenefici',
#  'aber',
#  'aberdeen',
#  'aberfoyl',
#  'abernook',
#  'aberr',
#  'abet',
#  'abett',
#  'abfab',
#  'abhor',
#  'abhorr',
#  'abi',
#  'abid',
#  'abiet',
#  'abigirl',
#  'abil',
#  'abililti',
#  'abilit',
#  'abit',
#  'abita',
#  'abiti',
#  'abj',
#  'abject',
#  'abk',
#  'abl',
#  'ablat',
#  'ablaz',
#  'ablet',
#  'abli',
#  'abliti',
#  'ablsolut',
#  'ablt',
#  'ablut',
#  'abmout',
#  'abnd',
#  'abnorm',
#  'abnormalitywith',
#  'abnormalti',
#  'abnoxi',
#  'aboard',
#  'abod',
#  'aboiut',
#  'abolit',
#  'abolitionist',
#  'abolult',
#  'abolut',
#  'abolutley',
#  'abomin',
#  'abond',
#  'abondanza',
#  'aboout',
#  'abor',
#  'aborb',
#  'aborio',
#  'abort',
#  'aboslut',
#  'abosolut',
#  'abosout',
#  'abosrb',
#  'abosult',
#  'abosut',
#  'abot',
#  'aboth',
#  'abottl',
#  'abotu',
#  'abou',
#  'aboug',
#  'abouit',
#  'aboulut',
#  'abound',
#  'abour',
#  'aboutfact',
#  'abouth',
#  'abouut',
#  'abouy',
#  'abouyt',
#  'abov',
#  'abovement',
#  'aboveour',
#  'abovi',
#  'abowt',
#  'abp',
#  'abpt',
#  'abpv',
#  'abq',
#  'abra',
#  'abrad',
#  'abraham',
#  'abras',
#  'abreast',
#  'abreva',
#  'abrevi',
#  'abridg',
#  'abrir',
#  'abroa',
#  'abroad',
#  'abrook',
#  'abrotanum',
#  'abrubt',
#  'abrupt',
#  'abruzzi',
#  'abruzzo',
#  'absalut',
#  'abscess',
#  'abscond',
#  'absenc',
#  'absens',
#  'absensc',
#  'absent',
#  'absentmind',
#  'absinth',
#  'absinthett',
#  'absinthium',
#  'abslut',
#  'abso',
#  'absofrigginlut',
#  'absolet',
#  'absolout',
#  'absolt',
#  'absolu',
#  'absoluet',
#  'absoluey',
#  'absoluit',
#  'absoluley',
#  'absolultey',
#  'absolulti',
#  'absolulut',
#  'absolust',
#  'absolut',
#  'absolutali',
#  'absolutament',
#  'absoluteki',
#  'absolutel',
#  'absoluteley',
#  'absolutelli',
#  'absolutelt',
#  'absolutelti',
#  'absoluteti',
#  'absolutey',
#  'absolutl',
#  'absolutley',
#  'absolutt',
#  'absolutuley',
#  'absolv',
#  'absoprt',
#  'absorb',
#  'absorbt',
#  'absorpt',
#  'absort',
#  'absoslut',
#  'absoulout',
#  'absoult',
#  'absoultey',
#  'absoulut',
#  'absouluti',
#  'absout',
#  'abstain',
#  'abstemi',
#  'abstin',
#  'abstract',
#  'absulut',
#  'absur',
#  'absurd',
#  'absurt',
#  'abswer',
#  'abt',
#  'abu',
#  'abud',
#  'abuela',
#  'abuelita',
#  'abum',
#  'abund',
#  'abundand',
#  'abundunc',
#  'abus',
#  'abut',
#  'abv',
#  'abvious',
#  'abysm',
#  'abyss',
#  'abyssian',
#  'abyssinian',
#  'ac',
#  'aca',
#  'acabar',
#  'acabaron',
#  'acabica',
#  'acacai',
#  'acacia',
#  'acadami',
#  'academ',
#  'academi',
#  'academia',
#  'acadia',
#  'acadian',
#  'acai',
#  'acaia',
#  'acaiberri',
#  'acallin',
#  'acan',
#  'acana',
#  'acapulco',
#  'acc',
#  'accas',
#  'accedi',
#  'accel',
#  'accelarad',
#  'acceler',
#  'accelerad',
#  'accent',
#  'accentu',
#  'accenu',
#  'accepet',
#  'accept',
#  'acceptal',
#  'acceptalbl',
#  'acceptd',
#  'acces',
#  'acceses',
#  'accesori',
#  'access',
#  'accessor',
#  'accessori',
#  'accid',
#  'accidc',
#  'acciden',
#  'accident',
#  'accidentaley',
#  'accidentali',
#  'accidentley',
#  'accient',
#  'acciugh',
#  'acclaim',
#  'acclam',
#  'acclim',
#  'acclimat',
#  'accod',
#  'accolad',
#  'accomad',
#  'accomd',
#  'accomid',
#  'accommod',
#  'accomod',
#  'accomond',
#  'accompain',
#  'accompani',
#  'accompany',
#  'accomplani',
#  'accompli',
#  'accomplic',
#  'accomplish',
#  'accoord',
#  'accor',
#  'accord',
#  'accordi',
#  'accordian',
#  'according',
#  'accordion',
#  'accordng',
#  'accost',
#  'accostom',
#  'accostum',
#  'account',
#  'accourd',
#  'accoustom',
#  'accouter',
#  'accoutr',
#  'accoutra',
#  'accpet',
#  'accredit',
#  'accross',
#  'accru',
#  'acct',
#  'acctual',
#  'acctuali',
#  'acctural',
#  'accuaint',
#  'accual',
#  'accuali',
#  'accuir',
#  'accumil',
#  'accummil',
#  'accumstom',
#  'accumul',
#  'accumult',
#  'accupuncturest',
#  'accupuncturist',
#  'accur',
#  'accuraci',
#  'accuracti',
#  'accurat',
#  'accus',
#  'accusatori',
#  'accustom',
#  'accusttom',
#  'accustum',
#  'accutan',
#  'accutec',
#  'accuweight',
#  'acd',
#  'acdept',
#  'ace',
#  'acecook',
#  'aced',
#  'acefulfam',
#  'acehardwareoutlet',
#  'aceit',
#  'aceita',
#  'acelfam',
#  'acent',
#  'aceola',
#  'aceoss',
#  'acepromazin',
#  'acer',
#  'acerb',
#  'acerola',
#  'acess',
#  'acesufam',
#  'acesuflamek',
#  'acesulf',
#  'acesulfam',
#  'acet',
#  'acetaia',
#  'acetaminophen',
#  'aceto',
#  'aceton',
#  'acetonitril',
#  'acetum',
#  'acetyl',
#  'acetylcholin',
#  'ach',
#  'achaar',
#  'achai',
#  'achallang',
#  'achar',
#  'achdut',
#  'acheiv',
#  'achey',
#  'achi',
#  'achieapalgo',
#  'achiev',
#  'achill',
#  'achin',
#  'achiot',
#  'achip',
#  'achiva',
#  'acht',
#  'achva',
#  'aci',
#  'acia',
#  'acic',
#  'acicif',
#  'acid',
#  'acidet',
#  'acidez',
#  'acidi',
#  'acidid',
#  'acidif',
#  'acidifi',
#  'acidilactici',
#  'acido',
#  'acidolphilus',
#  'acidophil',
#  'acidophilus',
#  'acidophuilus',
#  'acidosi',
#  'acidul',
#  'acini',
#  'aciphex',
#  'acit',
#  'acitid',
#  'ack',
#  'ackag',
#  'acke',
#  'acker',
#  'acki',
#  'acknowled',
#  'acknowledg',
#  'acknowleg',
#  'ackward',
#  'acl',
#  'aclu',
#  'acm',
#  'acn',
#  'acneic',
#  'acnet',
#  'acommod',
#  'acompani',
#  'acomplish',
#  'acontinu',
#  'acorb',
#  'acord',
#  'acorn',
#  'acorss',
#  'acosta',
#  'acostom',
#  'acould',
#  'acount',
#  'acoupl',
#  'acoust',
#  'acpuncturist',
#  'acquaint',
#  'acquarium',
#  'acquerello',
#  'acquies',
#  'acquiesc',
#  'acquint',
#  'acquir',
#  'acquisit',
#  'acquista',
#  'acquistato',
#  'acquisti',
#  'acquit',
#  'acr',
#  'acreag',
#  'acrid',
#  'acrimoni',
#  'acrobat',
#  'acromyn',
#  'acronym',
#  'acrospir',
#  'acruakki',
#  'acryl',
#  'acspect',
#  'acss',
#  'acsulfam',
#  'act',
#  'actal',
#  'actaual',
#  'actaulli',
#  'actifici',
#  'actii',
#  'actin',
#  'action',
#  'activ',
#  'activa',
#  'activateand',
#  'activeon',
#  'activepdf',
#  'activi',
#  'activia',
#  'activin',
#  'activist',
#  'activit',
#  'activiy',
#  'activli',
#  'activo',
#  'activwat',
#  'actlli',
#  'actor',
#  'actress',
#  'actua',
#  'actual',
#  'actuali',
#  'actualla',
#  'actualti',
#  'actualyl',
#  'actuat',
#  'actulli',
#  'actur',
#  'actviti',
#  'acual',
#  'acuiti',
#  'acumen',
#  'acupressur',
#  'acupunctur',
#  'acupuncturist',
#  'acur',
#  'acura',
#  'acuraci',
#  'acustom',
#  'acusul',
#  'acut',
#  'acutu',
#  'acv',
#  'acyual',
#  'ad',
#  'ada',
#  'adabi',
#  'adad',
#  'adag',
#  'adagio',
#  'adagiotea',
#  'adaigo',
#  'adam',
#  'adama',
#  'adamba',
#  'adament',
#  'adamn',
#  'adamo',
#  'adamovich',
#  'adamson',
#  'adana',
#  'adapt',
#  'adapta',
#  'adaptagen',
#  'adaptogen',
#  'adaptor',
#  'adav',
#  'aday',
#  'adbsorb',
#  'adc',
#  'add',
#  'adda',
#  'addact',
#  'addag',
#  'addam',
#  'addat',
#  'added',
#  'addend',
#  'addendum',
#  'adder',
#  'adderal',
#  'adderr',
#  'addi',
#  'addic',
#  'addicit',
#  'addiciton',
#  'addicitv',
#  'addick',
#  'addict',
#  'addident',
#  'addiion',
#  'addin',
#  'addingh',
#  'addinglarg',
#  'addison',
#  'addit',
#  'additav',
#  'additc',
#  'additct',
#  'additiion',
#  'additin',
#  'additiona',
#  'additionali',
#  'additionn',
#  'additioon',
#  'additit',
#  'additoion',
#  'additon',
#  'additt',
#  'addiv',
#  'addivit',
#  'addl',
#  'addmit',
#  'addmixur',
#  'addng',
#  'addres',
#  'address',
#  'addt',
#  'addtic',
#  'addtion',
#  'addtit',
#  'addtiv',
#  'addvertis',
#  'ade',
#  'adel',
#  'adela',
#  'adelaid',
#  'adelin',
#  'adell',
#  'adelman',
#  'adem',
#  'adema',
#  'adenium',
#  'adenosin',
#  'adept',
#  'adequ',
#  'adequa',
#  'adequaci',
#  'adequan',
#  'adequit',
#  'aderal',
#  'aderezar',
#  'adevrtis',
#  'adfvnouadv',
#  'adhd',
#  'adhear',
#  'adher',
#  'adhes',
#  'adiago',
#  'adian',
#  'adic',
#  'adicionalmenr',
#  'adicit',
#  'adict',
#  'adicta',
#  'adicti',
#  'adida',
#  'adigo',
#  'adiiton',
#  'adimitid',
#  'adina',
#  'adio',
#  'adipocyt',
#  'adipos',
#  'adirondack',
#  'adistribut',
#  'adit',
#  'adivc',
#  'adjac',
#  'adject',
#  'adjectiv',
#  'adjoin',
#  'adjudg',
#  'adjunct',
#  'adjus',
#  'adjust',
#  'adkin',
#  'adl',
#  'adm',
#  'admin',
#  'administ',
#  'administr',
#  'adminst',
#  'admir',
#  'admiss',
#  'admist',
#  'admit',
#  'admitt',
#  'admittit',
#  'admixtur',
#  'admmit',
#  'admoit',
#  'admonish',
#  'admonit',
#  'adn',
#  'ado',
#  'adob',
#  'adobada',
#  'adobo',
#  'adolesc',
#  'adolf',
#  'adolph',
#  'adolphus',
#  'adomin',
#  'adoni',
#  'adop',
#  'adopt',
#  'adopte',
#  'adoptogen',
#  'ador',
#  'adora',
#  'adorn',
#  'adot',
#  'adovada',
#  'adquat',
#  'adquir',
#  'adquirir',
#  'adquirirla',
#  'adr',
#  'adren',
#  'adrenalin',
#  'adress',
#  'adria',
#  'adrian',
#  'adriana',
#  'adriann',
#  'adrianna',
#  'adriat',
#  'adric',
#  'adrienn',
#  'adrift',
#  'adro',
#  'adsorb',
#  'adsoulut',
#  'adt',
#  'adujst',
#  'aduki',
#  'adul',
#  'aduli',
#  'adullt',
#  'adult',
#  'adulter',
#  'adulteru',
#  'adulthood',
#  'adultl',
#  'adultlif',
#  'adultur',
#  'adust',
#  'adv',
#  'advanatag',
#  'advanatg',
#  'advanc',
#  'advanceshield',
#  'advantag',
#  'advantaga',
#  'advantedg',
#  'advantix',
#  'advantra',
#  'advatag',
#  'advenst',
#  'advent',
#  'adventer',
#  'adventersom',
#  'adventist',
#  'adventur',
#  'adventuremong',
#  'adventuresom',
#  'adventursom',
#  'adver',
#  'adverag',
#  'adverb',
#  'adveris',
#  'advers',
#  'adversari',
#  'adversis',
#  'adversit',
#  'adversli',
#  'adverst',
#  'adverstis',
#  'advert',
#  'advertis',
#  'advertisi',
#  'advertisibg',
#  'advertist',
#  'advertiz',
#  'advertos',
#  'adverts',
#  'advetis',
#  'adviac',
#  'advic',
#  'advid',
#  'advie',
#  'advil',
#  'advion',
#  'advirtis',
#  'advis',
#  'advisor',
#  'advisori',
#  'adviz',
#  'advo',
#  'advoc',
#  'advocaci',
#  'advocado',
#  'advocar',
#  'advoid',
#  'adwanc',
#  'adzuki',
#  'ae',
#  'aearat',
#  'aebleskiv',
#  'aed',
#  'aegean',
#  'aenesthat',
#  'aenough',
#  'aeound',
#  'aer',
#  'aerat',
#  'aeratr',
#  'aeri',
#  'aerial',
#  'aeriskitchenwithsempio',
#  'aermican',
#  'aero',
#  'aerob',
#  'aerobe',
#  'aerobi',
#  'aerocat',
#  'aeroccino',
#  'aerochino',
#  'aerocrap',
#  'aerodynam',
#  'aerogardem',
#  'aerogarden',
#  'aerogod',
#  'aerogrow',
#  'aerolatt',
#  'aeromar',
#  'aeromat',
#  'aeropon',
#  'aeropress',
#  'aeroshot',
#  'aerosol',
#  'aeround',
#  'aesom',
#  'aesop',
#  'aestet',
#  'aestevium',
#  'aesthet',
#  'aesthetican',
#  'aesthic',
#  'aestivum',
#  'aestvum',
#  'aet',
#  'aeteri',
#  'aethest',
#  'aethet',
#  'aew',
#  'af',
#  'afaid',
#  'afaik',
#  'afair',
#  'afalat',
#  'afar',
#  'afaraid',
#  'afat',
#  'afb',
#  'afer',
#  'afernoon',
#  'afertast',
#  'afetr',
#  'afew',
#  'affabl',
#  'affaid',
#  'affair',
#  'affco',
#  'affeciando',
#  'affecionado',
#  'affect',
#  'affectianco',
#  'affection',
#  'affectionado',
#  'affectionato',
#  'affenpinsch',
#  'affer',
#  'affi',
#  'afficiado',
#  'afficianado',
#  'afficiando',
#  'afficiano',
#  'afficianodo',
#  'afficiaonado',
#  'afficinado',
#  'afficinatdo',
#  'afficionada',
#  'afficionado',
#  'afficionda',
#  'afficiondo',
#  'afficitionado',
#  'affictionado',
#  'affidabil',
#  'affigato',
#  'affili',
#  'affin',
#  'affinato',
#  'affinoi',
#  'affirm',
#  'affix',
#  'affliat',
#  'afflict',
#  'affluenc',
#  'affluent',
#  'affod',
#  'affogato',
#  'affor',
#  'afforad',
#  'afforadab',
#  'afford',
#  'affordablil',
#  'affordbl',
#  'afforment',
#  'afforrdal',
#  'affort',
#  'affraid',
#  'affresh',
#  'affront',
#  'afganastan',
#  'afganistan',
#  'afghan',
#  'afghanastan',
#  'afghani',
#  'afghanistan',
#  'afghnistan',
#  'afi',
#  'aficianado',
#  'aficianato',
#  'aficiando',
#  'aficienado',
#  'aficionada',
#  'aficionado',
#  'afield',
#  'afionado',
#  'afir',
#  'afix',
#  'aflam',
#  'aflatoxin',
#  'afloat',
#  'aflotoxin',
#  'afnkjganfpbgneonb',
#  'afoot',
#  'afor',
#  'aford',
#  'aforecalcul',
#  'aforement',
#  'aforemet',
#  'aforesaid',
#  'aforment',
#  'afr',
#  'afra',
#  'afrad',
#  'afraid',
#  'afriad',
#  'africa',
#  'africaf',
#  'african',
#  'africana',
#  'africanhut',
#  'africanredteacompani',
#  'africian',
#  'afrika',
#  'afrikaan',
#  'afrikan',
#  'afrin',
#  'afro',
#  'afront',
#  'afrotextur',
#  'aft',
#  'aften',
#  'afteraffect',
#  'afteral',
#  'afterast',
#  'afterbirth',
#  'afterbit',
#  'afterburn',
#  'aftercar',
#  'afterdeath',
#  'afterdinn',
#  'afterdnoon',
#  'aftereffect',
#  ...]

# %% [markdown]
# ## Use ML Algorithm to predict the label (negative/ positive)

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=4, shuffle=True, random_state=1)
lst_accu_stratified = []

# %%
from sklearn import naive_bayes
Naive = naive_bayes.MultinomialNB()

# %%
for train_index, test_index in skf.split(X, y):
    X_train_fold, X_test_fold = X[train_index], X[test_index]
    y_train_fold, y_test_fold = y[train_index], y[test_index]
    
    Tfidf_vect = TfidfVectorizer(stop_words='english', max_df=0.8, dtype= np.float32)
    Tfidf_vect.fit(X_train_fold)
    
    X_train_Tfidf = Tfidf_vect.transform(X_train_fold)
    X_test_Tfidf = Tfidf_vect.transform(X_test_fold)
    Naive.fit(X_train_Tfidf, y_train_fold)
    y_pred = Naive.predict(X_test_Tfidf)
    lst_accu_stratified.append(f1_score(y_test_fold, y_pred))

# %%
print('List of possible F1 score:', lst_accu_stratified)
print('\nMaximum F1 score That can be obtained from this model is:',
      max(lst_accu_stratified)*100, '%')
print('\nMinimum F1 score:',
      min(lst_accu_stratified)*100, '%')
print('\nOverall F1 score:',
      mean(lst_accu_stratified)*100, '%')
print('\nStandard Deviation is:', stdev(lst_accu_stratified))
# Out:
# List of possible F1 score: [0.8914590332213512, 0.8911640381307757, 0.8911468261602047, 0.8909237153781592]
#
# Maximum F1 score That can be obtained from this model is: 89.14590332213513 %
#
# Minimum F1 score: 89.09237153781592 %
#
# Overall F1 score: 89.11734032226228 %
#
# Standard Deviation is: 0.00021963800599970014

# %% [markdown]
# ## SGD Classifier

# %%
from sklearn.linear_model import SGDClassifier
sgd = SGDClassifier()

# %%
lst_accu_stratified_sgd = []
for train_index, test_index in skf.split(X, y):
    X_train_fold, X_test_fold = X[train_index], X[test_index]
    y_train_fold, y_test_fold = y[train_index], y[test_index]
    
    Tfidf_vect = TfidfVectorizer(stop_words='english', max_df=0.8, dtype= np.float32)
    Tfidf_vect.fit(X_train_fold)
    
    X_train_Tfidf = Tfidf_vect.transform(X_train_fold)
    X_test_Tfidf = Tfidf_vect.transform(X_test_fold)
    sgd.fit(X_train_Tfidf, y_train_fold)

    y_pred = sgd.predict(X_test_Tfidf)
    lst_accu_stratified_sgd.append(f1_score(y_test_fold, y_pred))

# %%
print('List of possible F1 score:', lst_accu_stratified_sgd)
print('\nMaximum F1 score That can be obtained from this model is:',
      max(lst_accu_stratified_sgd)*100, '%')
print('\nMinimum F1 score:',
      min(lst_accu_stratified_sgd)*100, '%')
print('\nOverall F1 score:',
      mean(lst_accu_stratified_sgd)*100, '%')
print('\nStandard Deviation is:', stdev(lst_accu_stratified_sgd))
# Out:
# List of possible F1 score: [0.918450211579385, 0.9183829511325337, 0.9182471484052476, 0.917640304642314]
#
# Maximum F1 score That can be obtained from this model is: 91.8450211579385 %
#
# Minimum F1 score: 91.76403046423141 %
#
# Overall F1 score: 91.81801539398701 %
#
# Standard Deviation is: 0.00036967704485381517

# %%
importances = sgd.coef_.tolist()[0]
#importances = Naive.feature_importances_
indices = np.argsort(importances)
features = Tfidf_vect.get_feature_names()

imp_df = pd.DataFrame({'Feature':[features[i] for i in indices],'Importance': [importances[i] for i in indices]})
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
print(imp_df.tail(10)) #top 10 most positive words
# Out:
#        Feature  Importance
# 64373  favorit    1.830844
# 64374   awesom    1.851652
# 64375     good    2.134706
# 64376     amaz    2.154049
# 64377    excel    2.489259
# 64378  perfect    2.716438
# 64379   delici    3.026104
# 64380     love    3.066141
# 64381     best    3.344341
# 64382    great    3.987900

# %%
print(imp_df.head(10)) #top 10 most negative words
# Out:
#       Feature  Importance
# 0  disappoint   -4.488774
# 1       worst   -3.522368
# 2          ok   -3.468223
# 3      return   -3.306934
# 4          aw   -3.040941
# 5    unfortun   -2.956783
# 6     terribl   -2.927215
# 7     horribl   -2.865595
# 8        okay   -2.714790
# 9       bland   -2.639161

# %% [markdown]
# ## Dimentionality Reduction

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

Tfidf_vect_svd = TfidfVectorizer(stop_words='english', max_df=0.8, dtype= np.float32)
Tfidf_vect_svd.fit(X_train)
    
X_train_Tfidf_svd = Tfidf_vect_svd.transform(X_train)
X_test_Tfidf_svd = Tfidf_vect_svd.transform(X_test)

# %%
from sklearn.decomposition import TruncatedSVD
svd = TruncatedSVD(n_components = 100) # n_components = 100, as recommended in sklearn documentation

X_train_svd = svd.fit_transform(X_train_Tfidf_svd, y_train)
X_test_svd = svd.transform(X_test_Tfidf_svd)

# %%
svd.explained_variance_ratio_
# Out:
# array([0.00336754, 0.00920605, 0.00873247, 0.00607381, 0.00520763,
#        0.00438224, 0.00394556, 0.00369774, 0.00356199, 0.0035139 ,
#        0.00336865, 0.00326978, 0.00320677, 0.00314526, 0.0030553 ,
#        0.002951  , 0.00289857, 0.00282251, 0.00265473, 0.0025899 ,
#        0.00254021, 0.00252584, 0.00252072, 0.00242683, 0.00237731,
#        0.00237117, 0.00230685, 0.00227535, 0.00226593, 0.00219792,
#        0.00211904, 0.00210478, 0.00208849, 0.0020585 , 0.00202972,
#        0.00198882, 0.00195961, 0.0019215 , 0.00190299, 0.0018793 ,
#        0.00187089, 0.00185326, 0.00182584, 0.00180979, 0.00179237,
#        0.00175463, 0.00175282, 0.00171879, 0.001703  , 0.00169518,
#        0.00167955, 0.00167625, 0.00165775, 0.00163765, 0.00162429,
#        0.00161658, 0.00160447, 0.00159014, 0.00158354, 0.00156051,
#        0.00154829, 0.00153724, 0.00153277, 0.00151346, 0.00149404,
#        0.00147371, 0.00146221, 0.00145614, 0.00144671, 0.00143112,
#        0.00142872, 0.0014095 , 0.00140326, 0.0013943 , 0.00137732,
#        0.00136497, 0.00135281, 0.0013449 , 0.00133132, 0.00132569,
#        0.00131135, 0.00128456, 0.00127968, 0.00127409, 0.00126154,
#        0.00125972, 0.00124875, 0.00124129, 0.00122705, 0.00121296,
#        0.00121142, 0.00120571, 0.00119215, 0.00118458, 0.00118245,
#        0.00116901, 0.00115552, 0.00115127, 0.00113102, 0.00113027],
#       dtype=float32)

# %%
len(svd.explained_variance_ratio_)
# Out:
# 100

# %%
sgd_sdv = SGDClassifier()
sgd_sdv.fit(X_train_svd, y_train)
y_pred_sgd_sdv = sgd_sdv.predict(X_test_svd)

print("F1 Score: ", f1_score(y_test, y_pred_sgd_sdv))
# Out:
# F1 Score:  0.8938094588098446

# %%
svd1 = TruncatedSVD(n_components = 500) # try to increase the number of components

X_train_svd1 = svd1.fit_transform(X_train_Tfidf_svd, y_train)
X_test_svd1 = svd1.transform(X_test_Tfidf_svd)

# %%
sgd_sdv1 = SGDClassifier()
sgd_sdv1.fit(X_train_svd1, y_train)
y_pred_sgd_sdv1 = sgd_sdv1.predict(X_test_svd1)

print("F1 Score: ", f1_score(y_test, y_pred_sgd_sdv1))
# Out:
# F1 Score:  0.9095921019077342

# %% [markdown]
# We can keep 500 components from SVD, instead of all 73780 features of TFIDF.

# %% [markdown]
# ## Bigram

# %%
import nltk

# %%
tfidf_n = TfidfVectorizer(stop_words='english', max_df=0.8, dtype= np.float32, ngram_range=(2))

# %%
sgd_bi = SGDClassifier()
lst_accu_stratified_bi = []

for train_index, test_index in skf.split(X, y):
    X_train_fold, X_test_fold = X[train_index], X[test_index]
    y_train_fold, y_test_fold = y[train_index], y[test_index]
    
    Tfidf_bi = TfidfVectorizer(stop_words='english', max_df=0.8, dtype= np.float32,ngram_range=(2,2))
    Tfidf_bi.fit(X_train_fold)
    X_train_bi = Tfidf_bi.transform(X_train_fold)
    X_test_bi = Tfidf_bi.transform(X_test_fold)

    sgd_bi.fit(X_train_bi, y_train_fold)
    y_pred_bi = sgd_bi.predict(X_test_bi)
    lst_accu_stratified_bi.append(f1_score(y_test_fold, y_pred_bi))

# %%
print('List of possible F1 score:', lst_accu_stratified_bi)
print('\nMaximum F1 score That can be obtained from this model is:',
      max(lst_accu_stratified_bi)*100, '%')
print('\nMinimum F1 score:',
      min(lst_accu_stratified_bi)*100, '%')
print('\nOverall F1 score:',
      mean(lst_accu_stratified_bi)*100, '%')
print('\nStandard Deviation is:', stdev(lst_accu_stratified_bi))
# Out:
# List of possible F1 score: [0.8772421044210669, 0.8771679190834023, 0.8771919800243411, 0.8771677208861157]
#
# Maximum F1 score That can be obtained from this model is: 87.72421044210668 %
#
# Minimum F1 score: 87.71677208861158 %
#
# Overall F1 score: 87.71924311037314 %
#
# Standard Deviation is: 3.501940377826289e-05

# %%
features_bi = Tfidf_bi.get_feature_names()
len(features_bi)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# 2449463

# %%
importances_bi = sgd_bi.coef_.tolist()[0]
indices_bi = np.argsort(importances_bi)


imp_df_bi = pd.DataFrame({'Feature':[features_bi[i] for i in indices_bi],'Importance': [importances_bi[i] for i in indices_bi]})

# %%
print(imp_df_bi.tail(10)) #top 10 most positive bigram
# Out:
#                   Feature  Importance
# 2449453          far best    0.292919
# 2449454       realli good    0.299654
# 2449455         best tast    0.300389
# 2449456        love stuff    0.310013
# 2449457        great tast    0.319084
# 2449458       definit buy    0.335500
# 2449459     great product    0.344050
# 2449460        tast great    0.350020
# 2449461  pleasant surpris    0.428914
# 2449462    high recommend    0.690828

# %%
print(imp_df_bi.head(10)) #top 10 most negative words
# Out:
#               Feature  Importance
# 0          wast money   -5.883018
# 1              wo buy   -2.909699
# 2  disappoint product   -1.438679
# 3          threw away   -1.405127
# 4         buyer bewar   -1.340235
# 5           bad batch   -1.300711
# 6            wo order   -1.261163
# 7          throw away   -1.220730
# 8            tast bad   -1.210144
# 9             tast ok   -1.192638
